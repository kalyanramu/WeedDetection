# %%
#pip install pascal-voc-writer
import os
import yaml
import pascal_voc_writer
#from pascal_voc_writer import Writer

#Convert YAML MAsk File to VOC XML with Bounding Boxes
def convert_yamlmask2voc(in_yml, out_xml = ""):
    #Parse input file
    f = open(in_yml, "r")
    yml_data = yaml.load(f)
    img_fname = yml_data['filename']
    img_annotations = yml_data['annotation']
    
    #Open and create header for XML
    #To do: add file size
    writer = pascal_voc_writer.Writer(img_fname,-1,-1)
    
    #labels
    labels = set()
    
    #Add annotations fo robjects
    for img_annotation in img_annotations:
        #Get mask
        x1 = img_annotation['points']['x']
        y1 = img_annotation['points']['y']
        label = img_annotation['type']
        
        #debug
        labels.add(label) 
        #Find bounding box values
        try:
            min_x = min(x1); 
            min_y = min(y1); 
            max_x = max(x1); 
            max_y = max(y1)
            #print(min_x, min_y, max_x, max_y)
            writer.addObject(label, min_x, min_y, max_x, max_y)
        except Exception as e:
            print(e)
            print("Found invalid number of points in the mask, ignoring it")
    
    #Extract input filename without extension
    if out_xml == "":
        filename, file_extension = os.path.splitext(in_yml)
        writer.save(filename+'.xml')
        print("Created/Saved ", filename+'.xml')
    else:
        writer.save(out_xml)
        print("Created/Saved ", out_xml)
    
    print("labels: ", labels)

# %%
def get_files_withext(infolder, ext = '.txt'):
    files =[]
    for file in os.listdir(infolder):
        if file.endswith(ext):
            files.append(file)
    return files

def convert_yamlmask2vocfolder(in_folder_yml, out_folder_xml = None):
    print('input folder:',in_folder_yml)
    
    #get list of files in input folder
    yml_files = get_files_withext(in_folder_yml,'.yaml')
    
    #Create output folder if not provided by user
    if out_folder_xml is None:
        dest_path = os.path.join(in_folder_yml, 'out')
        if not os.path.exists(dest_path):
            os.makedirs(dest_path)
    else:
        dest_path = out_folder_xml
        
    print('out folder:', dest_path)
        
    #Convert YML files in input folder to VOC XML files in out folder
    for yml_file in yml_files:
        print(yml_file)
        filename, file_extension = os.path.splitext(yml_file)
        out_name = os.path.join(dest_path, filename+'.xml')
        in_name = os.path.join(in_folder_yml,yml_file)
        convert_yamlmask2voc(in_name, out_name)

# %%
convert_yamlmask2voc('//content/clouderizer/fastai-v1/data/weed/annotations/009_annotation.yaml')
# Out:
# 'float' object is not iterable
# Found invalid number of points in the mask, ignoring it
# Created/Saved  //content/clouderizer/fastai-v1/data/weed/annotations/009_annotation.xml
# labels:  {'weed', 'crop'}

# %%
inpath = '/content/clouderizer/fastai-v1/data/weed/annotations'
files_list = get_files_withext(inpath,'.yaml')

# %%
print(len(files_list))
# Out:
# 60

# %%
convert_yamlmask2vocfolder(inpath)
# Out:
# input folder: /content/clouderizer/fastai-v1/data/weed/annotations
# out folder: /content/clouderizer/fastai-v1/data/weed/annotations/out
# 013_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/013_annotation.xml
# labels:  {'weed', 'crop'}
# 022_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/022_annotation.xml
# labels:  {'weed', 'crop'}
# 060_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/060_annotation.xml
# labels:  {'weed', 'crop'}
# 011_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/011_annotation.xml
# labels:  {'weed', 'crop'}
# 055_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/055_annotation.xml
# labels:  {'weed', 'crop'}
# 058_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/058_annotation.xml
# labels:  {'weed', 'crop'}
# 041_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/041_annotation.xml
# labels:  {'weed', 'crop'}
# 021_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/021_annotation.xml
# labels:  {'weed', 'crop'}
# 024_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/024_annotation.xml
# labels:  {'weed', 'crop'}
# 005_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/005_annotation.xml
# labels:  {'weed', 'crop'}
# 053_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/053_annotation.xml
# labels:  {'weed', 'crop'}
# 016_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/016_annotation.xml
# labels:  {'weed', 'crop'}
# 003_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/003_annotation.xml
# labels:  {'weed', 'crop'}
# 051_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/051_annotation.xml
# labels:  {'weed', 'crop'}
# 018_annotation.yaml
# 'float' object is not iterable
# Found invalid number of points in the mask, ignoring it
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/018_annotation.xml
# labels:  {'weed', 'crop'}
# 043_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/043_annotation.xml
# labels:  {'weed', 'crop'}
# 015_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/015_annotation.xml
# labels:  {'weed', 'crop'}
# 028_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/028_annotation.xml
# labels:  {'weed', 'crop'}
# 056_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/056_annotation.xml
# labels:  {'weed', 'crop'}
# 033_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/033_annotation.xml
# labels:  {'weed', 'crop'}
# 009_annotation.yaml
# 'float' object is not iterable
# Found invalid number of points in the mask, ignoring it
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/009_annotation.xml
# labels:  {'weed', 'crop'}
# 026_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/026_annotation.xml
# labels:  {'weed', 'crop'}
# 032_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/032_annotation.xml
# labels:  {'weed', 'crop'}
# 010_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/010_annotation.xml
# labels:  {'weed', 'crop'}
# 049_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/049_annotation.xml
# labels:  {'weed', 'crop'}
# 025_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/025_annotation.xml
# labels:  {'weed', 'crop'}
# 031_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/031_annotation.xml
# labels:  {'weed', 'crop'}
# 044_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/044_annotation.xml
# labels:  {'weed', 'crop'}
# 042_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/042_annotation.xml
# labels:  {'weed', 'crop'}
# 001_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/001_annotation.xml
# labels:  {'weed', 'crop'}
# 046_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/046_annotation.xml
# labels:  {'weed', 'crop'}
# 047_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/047_annotation.xml
# labels:  {'weed', 'crop'}
# 014_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/014_annotation.xml
# labels:  {'weed', 'crop'}
# 007_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/007_annotation.xml
# labels:  {'weed', 'crop'}
# 052_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/052_annotation.xml
# labels:  {'weed', 'crop'}
# 045_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/045_annotation.xml
# labels:  {'weed', 'crop'}
# 035_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/035_annotation.xml
# labels:  {'weed', 'crop'}
# 027_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/027_annotation.xml
# labels:  {'weed', 'crop'}
# 050_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/050_annotation.xml
# labels:  {'crop'}
# 059_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/059_annotation.xml
# labels:  {'weed', 'crop'}
# 034_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/034_annotation.xml
# labels:  {'weed', 'crop'}
# 038_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/038_annotation.xml
# labels:  {'weed', 'crop'}
# 012_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/012_annotation.xml
# labels:  {'weed', 'crop'}
# 023_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/023_annotation.xml
# labels:  {'weed', 'crop'}
# 002_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/002_annotation.xml
# labels:  {'weed', 'crop'}
# 037_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/037_annotation.xml
# labels:  {'weed', 'crop'}
# 029_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/029_annotation.xml
# labels:  {'weed', 'crop'}
# 006_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/006_annotation.xml
# labels:  {'weed', 'crop'}
# 020_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/020_annotation.xml
# labels:  {'weed', 'crop'}
# 040_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/040_annotation.xml
# labels:  {'weed', 'crop'}
# 019_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/019_annotation.xml
# labels:  {'weed', 'crop'}
# 036_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/036_annotation.xml
# labels:  {'weed', 'crop'}
# 017_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/017_annotation.xml
# labels:  {'weed', 'crop'}
# 057_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/057_annotation.xml
# labels:  {'weed', 'crop'}
# 008_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/008_annotation.xml
# labels:  {'weed', 'crop'}
# 048_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/048_annotation.xml
# labels:  {'weed', 'crop'}
# 030_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/030_annotation.xml
# labels:  {'weed', 'crop'}
# 054_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/054_annotation.xml
# labels:  {'weed', 'crop'}
# 039_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/039_annotation.xml
# labels:  {'weed', 'crop'}
# 004_annotation.yaml
# Created/Saved  /content/clouderizer/fastai-v1/data/weed/annotations/out/004_annotation.xml
# labels:  {'weed', 'crop'}
